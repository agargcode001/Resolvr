# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('ResolvrData.csv')

# %%
data.describe()
# Out:
#          Customer ID            Age  Flight Distance  Inflight wifi service  \
# count  129880.000000  129880.000000    129880.000000          129876.000000
# mean    64940.500000      39.427957      1190.316392               2.728703
# std     37493.270818      15.119360       997.452477               1.329334
# min         1.000000       7.000000        31.000000               0.000000
# 25%     32470.750000      27.000000       414.000000               2.000000
# 50%     64940.500000      40.000000       844.000000               3.000000
# 75%     97410.250000      51.000000      1744.000000               4.000000
# max    129880.000000      85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      129876.000000           129877.000000
# mean                            3.057609                2.756885
# std                             1.526757                1.401742
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Customer ID                        129880 non-null  int64
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  object
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  object
#  5   Class                              129880 non-null  object
#  6   Flight Distance                    129880 non-null  int64
#  7   Inflight wifi service              129876 non-null  float64
#  8   Departure/Arrival time convenient  129876 non-null  float64
#  9   Ease of Online booking             129877 non-null  float64
#  10  Gate location                      129872 non-null  float64
# ...

# %%
data.head()
# Out:
#    Customer ID  Gender   Customer Type  Age   Type of Travel     Class  \
# 0       110028  Female  Loyal Customer   26  Business travel  Business
# 1       119299    Male  Loyal Customer   61  Business travel  Business
# 2       111157  Female  Loyal Customer   26  Personal Travel       Eco
# 3        96462  Female  Loyal Customer   52  Business travel  Business
# 4        79485  Female  Loyal Customer   41  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0             1142                    2.0                                2.0
# 1              214                    3.0                                3.0
# 2             1180                    3.0                                4.0
# 3             2035                    4.0                                3.0
# 4              853                    1.0                                2.0
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %%
sns.countplot(data['satisfaction'])

# %%
sns.boxplot(x=data['satisfaction'], y = data['Customer Type'])

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(data.corr())

# %%
sns.violinplot(x = data['satisfaction'], y = data['Departure Delay in Minutes'])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=target_names))

# %%
sns.countplot(data['Customer Type'], hue = data['satisfaction'])

# %%
sns.countplot(data['Gender'], hue = data['satisfaction'])

# %% [markdown]
# #Gender doesn't have much impact on satisfaction

# %%
sns.countplot(data['Type of Travel'], hue = data['satisfaction'])

# %%
sns.countplot(data['Type of Travel'], hue = data['Class'])

# %%
sns.countplot(data['Class'], hue = data['satisfaction'])

# %% [markdown]
# 1) People from economy class tend to more unsatisfied with the travel as compared to that with Buisness class, thus pointing out a possible scope for imporvement in the facilities provided in the Economy Class.
# 2) People going with the puprose of Buisness are gnerally more satisfied, the reason behind it could be value for money.

# %%
sns.violinplot(x = data['satisfaction'], y = data['Flight Distance'])

# %%
sns.boxplot(x = data['satisfaction'], y = data['Flight Distance'])

# %%
sns.boxplot(x = data['satisfaction'], y = data['Departure Delay in Minutes'])

# %% [markdown]
# Short Distance Flights tend to be more unsatisfactory.

# %%
data.columns
# Out:
# Index(['Customer ID', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
sns.countplot(data['Inflight wifi service'], hue = data['satisfaction'])

# %%
sns.countplot(data['Ease of Online booking'], hue = data['satisfaction'])

# %%
sns.countplot(data['Gate location'], hue = data['satisfaction'])

# %%
sns.countplot(data['Food and drink'], hue = data['satisfaction'])

# %%
sns.countplot(data['Food and drink'], hue = data['Class'])

# %%
sns.countplot(data.loc[data['Food and drink']==1, 'Class'], hue = data['satisfaction'])

# %%
sns.countplot(data['Online boarding'], hue = data['satisfaction'])

# %%
sns.countplot(data.loc[data['Online boarding']==2, 'Class'], hue = data['satisfaction'])

# %%
sns.countplot(data['Seat comfort'], hue = data['satisfaction'])

# %%
sns.countplot(data['Inflight entertainment'], hue = data['satisfaction'])

# %%
sns.countplot(data['On-board service'], hue = data['satisfaction'])

# %%
sns.countplot(data['Leg room service'], hue = data['satisfaction'])

# %%
sns.countplot(data['Baggage handling'], hue = data['satisfaction'])

# %%
sns.countplot(data['Inflight service'], hue = data['satisfaction'])

# %%
sns.countplot(data['Cleanliness'], hue = data['satisfaction'])
